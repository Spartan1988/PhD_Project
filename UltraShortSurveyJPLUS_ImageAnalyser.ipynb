# %%
from astropy.io import fits
#import pyfits
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
#matplotlib.rc_file("../../templates/matplotlibrc")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hdu_list = fits.open("j02-20170410T025351-01_prepro.fz")
hdu_list.info()
catalog = pyfits.open("j02-20170410T025351-01_prepro.proccat")
image_header = catalog[1].data[0][0]
data_catalog = catalog[2].data
#catalog
# Out:
# Filename: j02-20170410T025351-01_prepro.fz
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU       8   ()
#   1  COMPRESSED_IMAGE  CompImageHDU    736   (9216, 9232)   float32
#   2  MASKED PIXELS  CompImageHDU     19   (9216, 9232)   uint8

# %%
image_header = catalog[1].data[0][0]
print image_header
# Out:
# ['SIMPLE  =                    T / file does conform to FITS standard'
#  'BITPIX  =                  -32 / number of bits per data pixel'
#  'NAXIS   =                    2 / number of data axes'
#  'NAXIS1  =                 9216' 'NAXIS2  =                 9232'
#  'EXTEND  =                    T / FITS dataset may contain extensions'
#  "COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy"
#  "COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H"
#  "BUNIT   = 'adu'" "ORIGIN  = 'OAJ'"
#  "FILENAME= 'j02-20170410T025351-01_prepro.fits'" "TELESCOP= 'OAJ-T80'"
#  "INSTRUME= 'T80Cam'" "OBJECT  = 'HD095735off'" "PRJ_ID  = '1000096'"
#  "PRJ_VER = '11'" "OBS_ID  = '1'" "EXP_ID  = '36'" "OBSERVER= 'ROB'"
#  "PI-COI  = ''" "ORIGFILE= 'j02-20170410T025351-01.fits.fz'"
#  "DATE    = '2017-04-10T02:54:27.448'"
#  "DATE-OBS= '2017-04-10T02:53:51.897'"
#  "DATE-END= '2017-04-10T02:54:01.899'" 'EXPTIME = 10.000'
#  'RA      = 167.394981' 'DEC     = 35.96988' "RADECSYS= 'FK5'"
#  "TIMESYS = 'UTC'" 'AIRMASS = 1.80186'
#  'GAIN    =   0.9399999999999999 / mean gain (e-/ADU)'
#  "REFERENC= 'ESO-VLT-DIC.PRIMARY-FITS'" "FILTER  = 'zSDSS'"
#  'HIERARCH OAJ TEL EL START= 33.69572' 'HIERARCH OAJ TEL EL END= 33.66587'
#  'HIERARCH OAJ TEL AZ START= 291.08242'
#  'HIERARCH OAJ TEL AZ END= 291.10162' 'HIERARCH OAJ TEL GEOELEV= 2012'
#  'HIERARCH OAJ TEL GEOLAT= 40.0427' 'HIERARCH OAJ TEL GEOLON= -1.0165'
#  'HIERARCH OAJ TEL DOME AZ= 276.70000'
#  'HIERARCH OAJ TEL DOME TEMP= 5.65761'
#  'HIERARCH OAJ TEL DOME RHUM= 41.40983' "HIERARCH OAJ TEL OPER= 'ROB'"
#  'HIERARCH OAJ TEL FOCU LEN= 3.712' 'HIERARCH OAJ TEL FOCU SCALE= 55.56'
#  'HIERARCH OAJ TEL FOCU VALUE= -0.17500'
#  'HIERARCH OAJ TEL PARANG START= 61.83249'
#  'HIERARCH OAJ TEL PARANG END= 61.81865'
#  "HIERARCH OAJ TEL TRAK STATUS= 'TRACKING GOOD'"
#  'HIERARCH OAJ TEL AIRM START= 1.80115'
#  'HIERARCH OAJ TEL AIRM END= 1.80255'
#  'HIERARCH OAJ TEL MIRR S1 TEMP= 6.90000'
#  'HIERARCH OAJ TEL MIRR S2 TEMP= 7.46000'
#  'HIERARCH OAJ TEL FRONT RING TEMP= 5.21000'
#  'HIERARCH OAJ TEL TUBE ROD TEMP= 5.34000'
#  "HIERARCH OAJ TEL POINT MODE= 'NORMAL'"
#  'HIERARCH OAJ TEL HEXAPOD X= 0.5840000'
#  'HIERARCH OAJ TEL HEXAPOD Y= -0.5220000'
#  'HIERARCH OAJ TEL HEXAPOD Z= -0.1750000'
#  'HIERARCH OAJ TEL HEXAPOD U= -0.0320000'
#  'HIERARCH OAJ TEL HEXAPOD V= -0.0800000' "HIERARCH OAJ INS OPER= 'ROB'"
#  'HIERARCH OAJ INS TEMP= 0.0' 'HIERARCH OAJ INS PIXSCALE= 0.5556'
#  "HIERARCH OAJ DET NAME= 'e2v CCD290-99'" 'HIERARCH OAJ DET CCDS= 1'
#  'HIERARCH OAJ DET CHIPID= 0' 'HIERARCH OAJ DET NX= 9216'
#  'HIERARCH OAJ DET NY= 9232' 'HIERARCH OAJ DET PSZX= 10.'
#  'HIERARCH OAJ DET PSZY= 10.' 'HIERARCH OAJ DET TEMP= -111.0'
#  "HIERARCH OAJ DET EXP TYPE= 'LIGHT'"
#  "HIERARCH OAJ DET READ MODE= 'MODE_5'"
#  "HIERARCH OAJ DET READ SPEED= '500 KHz'"
#  "HIERARCH OAJ DET READ CLOCK= 'DSI 68, High Gain, 1x1'"
#  'HIERARCH OAJ DET OUTPUTS= 16' 'HIERARCH OAJ DET REQTIM= 10.0000'
#  'HIERARCH OAJ DET OUT1 ID= 00' 'HIERARCH OAJ DET OUT1 X= 1'
#  'HIERARCH OAJ DET OUT1 Y= 1' 'HIERARCH OAJ DET OUT1 NX= 1152'
#  'HIERARCH OAJ DET OUT1 NY= 4616'
#  "HIERARCH OAJ DET OUT1 PRSCX= '[1:27,1:4670]'"
#  "HIERARCH OAJ DET OUT1 PRSCY= ''"
#  "HIERARCH OAJ DET OUT1 OVSCX= '[1180:1206,1:4670]'"
#  "HIERARCH OAJ DET OUT1 OVSCY= '[1:1206,4617:4670]'"
#  "HIERARCH OAJ DET OUT1 IMSC= '[28:1179,1:4616]'"
#  'HIERARCH OAJ DET OUT1 GAIN= 0.94' 'HIERARCH OAJ DET OUT1 RON= 3.3300'
#  'HIERARCH OAJ DET OUT1 SATUR= 123500.0' 'HIERARCH OAJ DET OUT2 ID= 01'
#  'HIERARCH OAJ DET OUT2 X= 1207' 'HIERARCH OAJ DET OUT2 Y= 1'
#  'HIERARCH OAJ DET OUT2 NX= 1152' 'HIERARCH OAJ DET OUT2 NY= 4616'
#  "HIERARCH OAJ DET OUT2 PRSCX= '[1207:1233,1:4670]'"
#  "HIERARCH OAJ DET OUT2 PRSCY= ''"
#  "HIERARCH OAJ DET OUT2 OVSCX= '[2386:2412,1:4670]'"
#  "HIERARCH OAJ DET OUT2 OVSCY= '[1207:2412,4617:4670]'"
#  "HIERARCH OAJ DET OUT2 IMSC= '[1234:2385,1:4616]'"
#  'HIERARCH OAJ DET OUT2 GAIN= 0.94' 'HIERARCH OAJ DET OUT2 RON= 3.3600'
#  'HIERARCH OAJ DET OUT2 SATUR= 123000.0' 'HIERARCH OAJ DET OUT3 ID= 02'
#  'HIERARCH OAJ DET OUT3 X= 2413' 'HIERARCH OAJ DET OUT3 Y= 1'
#  'HIERARCH OAJ DET OUT3 NX= 1152' 'HIERARCH OAJ DET OUT3 NY= 4616'
#  "HIERARCH OAJ DET OUT3 PRSCX= '[2413:2439,1:4670]'"
#  "HIERARCH OAJ DET OUT3 PRSCY= ''"
#  "HIERARCH OAJ DET OUT3 OVSCX= '[3592:3618,1:4670]'"
#  "HIERARCH OAJ DET OUT3 OVSCY= '[2413:3618,4617:4670]'"
#  "HIERARCH OAJ DET OUT3 IMSC= '[2440:3591,1:4616]'"
#  'HIERARCH OAJ DET OUT3 GAIN= 0.94' 'HIERARCH OAJ DET OUT3 RON= 3.3600'
#  'HIERARCH OAJ DET OUT3 SATUR= 122100.0' 'HIERARCH OAJ DET OUT4 ID= 03'
#  'HIERARCH OAJ DET OUT4 X= 3619' 'HIERARCH OAJ DET OUT4 Y= 1'
#  'HIERARCH OAJ DET OUT4 NX= 1152' 'HIERARCH OAJ DET OUT4 NY= 4616'
#  "HIERARCH OAJ DET OUT4 PRSCX= '[3619:3645,1:4670]'"
#  "HIERARCH OAJ DET OUT4 PRSCY= ''"
#  "HIERARCH OAJ DET OUT4 OVSCX= '[4798:4824,1:4670]'"
#  "HIERARCH OAJ DET OUT4 OVSCY= '[3619:4824,4617:4670]'"
#  "HIERARCH OAJ DET OUT4 IMSC= '[3646:4797,1:4616]'"
#  'HIERARCH OAJ DET OUT4 GAIN= 0.93' 'HIERARCH OAJ DET OUT4 RON= 3.3600'
#  'HIERARCH OAJ DET OUT4 SATUR= 122400.0' 'HIERARCH OAJ DET OUT5 ID= 04'
#  'HIERARCH OAJ DET OUT5 X= 4825' 'HIERARCH OAJ DET OUT5 Y= 1'
#  'HIERARCH OAJ DET OUT5 NX= 1152' 'HIERARCH OAJ DET OUT5 NY= 4616'
#  "HIERARCH OAJ DET OUT5 PRSCX= '[6004:6030,1:4670]'"
#  "HIERARCH OAJ DET OUT5 PRSCY= ''"
#  "HIERARCH OAJ DET OUT5 OVSCX= '[4825:4851,1:4670]'"
#  "HIERARCH OAJ DET OUT5 OVSCY= '[4825:6030,4617:4670]'"
#  "HIERARCH OAJ DET OUT5 IMSC= '[4852:6003,1:4616]'"
#  'HIERARCH OAJ DET OUT5 GAIN= 0.93' 'HIERARCH OAJ DET OUT5 RON= 3.3400'
#  'HIERARCH OAJ DET OUT5 SATUR= 123600.0' 'HIERARCH OAJ DET OUT6 ID= 05'
#  'HIERARCH OAJ DET OUT6 X= 6031' 'HIERARCH OAJ DET OUT6 Y= 1'
#  'HIERARCH OAJ DET OUT6 NX= 1152' 'HIERARCH OAJ DET OUT6 NY= 4616'
#  "HIERARCH OAJ DET OUT6 PRSCX= '[7210:7236,1:4670]'"
#  "HIERARCH OAJ DET OUT6 PRSCY= ''"
#  "HIERARCH OAJ DET OUT6 OVSCX= '[6031:6057,1:4670]'"
#  "HIERARCH OAJ DET OUT6 OVSCY= '[6031:7236,4617:4670]'"
#  "HIERARCH OAJ DET OUT6 IMSC= '[6058:7209,1:4616]'"
#  'HIERARCH OAJ DET OUT6 GAIN= 0.93' 'HIERARCH OAJ DET OUT6 RON= 3.3800'
#  'HIERARCH OAJ DET OUT6 SATUR= 122000.0' 'HIERARCH OAJ DET OUT7 ID= 06'
#  'HIERARCH OAJ DET OUT7 X= 7237' 'HIERARCH OAJ DET OUT7 Y= 1'
#  'HIERARCH OAJ DET OUT7 NX= 1152' 'HIERARCH OAJ DET OUT7 NY= 4616'
#  "HIERARCH OAJ DET OUT7 PRSCX= '[8416:8442,1:4670]'"
#  "HIERARCH OAJ DET OUT7 PRSCY= ''"
#  "HIERARCH OAJ DET OUT7 OVSCX= '[7237:7263,1:4670]'"
#  "HIERARCH OAJ DET OUT7 OVSCY= '[7237:8442,4617:4670]'"
#  "HIERARCH OAJ DET OUT7 IMSC= '[7264:8415,1:4616]'"
#  'HIERARCH OAJ DET OUT7 GAIN= 0.92' 'HIERARCH OAJ DET OUT7 RON= 3.3600'
#  'HIERARCH OAJ DET OUT7 SATUR= 120700.0' 'HIERARCH OAJ DET OUT8 ID= 07'
#  'HIERARCH OAJ DET OUT8 X= 8443' 'HIERARCH OAJ DET OUT8 Y= 1'
#  'HIERARCH OAJ DET OUT8 NX= 1152' 'HIERARCH OAJ DET OUT8 NY= 4616'
#  "HIERARCH OAJ DET OUT8 PRSCX= '[9622:9648,1:4670]'"
#  "HIERARCH OAJ DET OUT8 PRSCY= ''"
#  "HIERARCH OAJ DET OUT8 OVSCX= '[8443:8469,1:4670]'"
#  "HIERARCH OAJ DET OUT8 OVSCY= '[8443:9648,4617:4670]'"
#  "HIERARCH OAJ DET OUT8 IMSC= '[8470:9621,1:4616]'"
#  'HIERARCH OAJ DET OUT8 GAIN= 0.92' 'HIERARCH OAJ DET OUT8 RON= 3.3500'
#  'HIERARCH OAJ DET OUT8 SATUR= 120500.0' 'HIERARCH OAJ DET OUT9 ID= 08'
#  'HIERARCH OAJ DET OUT9 X= 1' 'HIERARCH OAJ DET OUT9 Y= 4671'
#  'HIERARCH OAJ DET OUT9 NX= 1152' 'HIERARCH OAJ DET OUT9 NY= 4616'
#  "HIERARCH OAJ DET OUT9 PRSCX= '[1:27,4671:9340]'"
#  "HIERARCH OAJ DET OUT9 PRSCY= ''"
#  "HIERARCH OAJ DET OUT9 OVSCX= '[1180:1206,4671:9340]'"
#  "HIERARCH OAJ DET OUT9 OVSCY= '[1:1206,4671:4724]'"
#  "HIERARCH OAJ DET OUT9 IMSC= '[28:1179,4725:9340]'"
#  'HIERARCH OAJ DET OUT9 GAIN= 0.93' 'HIERARCH OAJ DET OUT9 RON= 3.3300'
#  'HIERARCH OAJ DET OUT9 SATUR= 124600.0' 'HIERARCH OAJ DET OUT10 ID= 09'
#  'HIERARCH OAJ DET OUT10 X= 1207' 'HIERARCH OAJ DET OUT10 Y= 4671'
#  'HIERARCH OAJ DET OUT10 NX= 1152' 'HIERARCH OAJ DET OUT10 NY= 4616'
#  "HIERARCH OAJ DET OUT10 PRSCX= '[1207:1233,4671:9340]'"
#  "HIERARCH OAJ DET OUT10 PRSCY= ''"
#  "HIERARCH OAJ DET OUT10 OVSCX= '[2386:2412,4671:9340]'"
#  "HIERARCH OAJ DET OUT10 OVSCY= '[1207:2412,4671:4724]'"
#  "HIERARCH OAJ DET OUT10 IMSC= '[1234:2385,4725:9340]'"
#  'HIERARCH OAJ DET OUT10 GAIN= 0.95' 'HIERARCH OAJ DET OUT10 RON= 3.3000'
#  'HIERARCH OAJ DET OUT10 SATUR= 123500.0' 'HIERARCH OAJ DET OUT11 ID= 10'
#  'HIERARCH OAJ DET OUT11 X= 2413' 'HIERARCH OAJ DET OUT11 Y= 4671'
#  'HIERARCH OAJ DET OUT11 NX= 1152' 'HIERARCH OAJ DET OUT11 NY= 4616'
#  "HIERARCH OAJ DET OUT11 PRSCX= '[2413:2439,4671:9340]'"
#  "HIERARCH OAJ DET OUT11 PRSCY= ''"
#  "HIERARCH OAJ DET OUT11 OVSCX= '[3592:3618,4671:9340]'"
#  "HIERARCH OAJ DET OUT11 OVSCY= '[2413:3618,4671:4724]'"
#  "HIERARCH OAJ DET OUT11 IMSC= '[2440:3591,4725:9340]'"
#  'HIERARCH OAJ DET OUT11 GAIN= 0.94' 'HIERARCH OAJ DET OUT11 RON= 3.3000'
#  'HIERARCH OAJ DET OUT11 SATUR= 123100.0' 'HIERARCH OAJ DET OUT12 ID= 11'
#  'HIERARCH OAJ DET OUT12 X= 3619' 'HIERARCH OAJ DET OUT12 Y= 4671'
#  'HIERARCH OAJ DET OUT12 NX= 1152' 'HIERARCH OAJ DET OUT12 NY= 4616'
#  "HIERARCH OAJ DET OUT12 PRSCX= '[3619:3645,4671:9340]'"
#  "HIERARCH OAJ DET OUT12 PRSCY= ''"
#  "HIERARCH OAJ DET OUT12 OVSCX= '[4798:4824,4671:9340]'"
#  "HIERARCH OAJ DET OUT12 OVSCY= '[3619:4824,4671:4724]'"
#  "HIERARCH OAJ DET OUT12 IMSC= '[3646:4797,4725:9340]'"
#  'HIERARCH OAJ DET OUT12 GAIN= 0.94' 'HIERARCH OAJ DET OUT12 RON= 4.2300'
#  'HIERARCH OAJ DET OUT12 SATUR= 123500.0' 'HIERARCH OAJ DET OUT13 ID= 12'
#  'HIERARCH OAJ DET OUT13 X= 4825' 'HIERARCH OAJ DET OUT13 Y= 4671'
#  'HIERARCH OAJ DET OUT13 NX= 1152' 'HIERARCH OAJ DET OUT13 NY= 4616'
#  "HIERARCH OAJ DET OUT13 PRSCX= '[6004:6030,4671:9340]'"
#  "HIERARCH OAJ DET OUT13 PRSCY= ''"
#  "HIERARCH OAJ DET OUT13 OVSCX= '[4825:4851,4671:9340]'"
#  "HIERARCH OAJ DET OUT13 OVSCY= '[4825:6030,4671:4724]'"
#  "HIERARCH OAJ DET OUT13 IMSC= '[4852:6003,4725:9340]'"
#  'HIERARCH OAJ DET OUT13 GAIN= 0.93' 'HIERARCH OAJ DET OUT13 RON= 3.3300'
#  'HIERARCH OAJ DET OUT13 SATUR= 122300.0' 'HIERARCH OAJ DET OUT14 ID= 13'
#  'HIERARCH OAJ DET OUT14 X= 6031' 'HIERARCH OAJ DET OUT14 Y= 4671'
#  'HIERARCH OAJ DET OUT14 NX= 1152' 'HIERARCH OAJ DET OUT14 NY= 4616'
#  "HIERARCH OAJ DET OUT14 PRSCX= '[7210:7236,4671:9340]'"
#  "HIERARCH OAJ DET OUT14 PRSCY= ''"
#  "HIERARCH OAJ DET OUT14 OVSCX= '[6031:6057,4671:9340]'"
#  "HIERARCH OAJ DET OUT14 OVSCY= '[6031:7236,4671:4724]'"
#  "HIERARCH OAJ DET OUT14 IMSC= '[6058:7209,4725:9340]'"
#  'HIERARCH OAJ DET OUT14 GAIN= 0.93' 'HIERARCH OAJ DET OUT14 RON= 3.3200'
#  'HIERARCH OAJ DET OUT14 SATUR= 121700.0' 'HIERARCH OAJ DET OUT15 ID= 14'
#  'HIERARCH OAJ DET OUT15 X= 7237' 'HIERARCH OAJ DET OUT15 Y= 4671'
#  'HIERARCH OAJ DET OUT15 NX= 1152' 'HIERARCH OAJ DET OUT15 NY= 4616'
#  "HIERARCH OAJ DET OUT15 PRSCX= '[8416:8442,4671:9340]'"
#  "HIERARCH OAJ DET OUT15 PRSCY= ''"
#  "HIERARCH OAJ DET OUT15 OVSCX= '[7237:7263,4671:9340]'"
#  "HIERARCH OAJ DET OUT15 OVSCY= '[7237:8442,4671:4724]'"
#  "HIERARCH OAJ DET OUT15 IMSC= '[7264:8415,4725:9340]'"
#  'HIERARCH OAJ DET OUT15 GAIN= 0.94' 'HIERARCH OAJ DET OUT15 RON= 3.3600'
#  'HIERARCH OAJ DET OUT15 SATUR= 123000.0' 'HIERARCH OAJ DET OUT16 ID= 15'
#  'HIERARCH OAJ DET OUT16 X= 8443' 'HIERARCH OAJ DET OUT16 Y= 4671'
#  'HIERARCH OAJ DET OUT16 NX= 1152' 'HIERARCH OAJ DET OUT16 NY= 4616'
#  "HIERARCH OAJ DET OUT16 PRSCX= '[9622:9648,4671:9340]'"
#  "HIERARCH OAJ DET OUT16 PRSCY= ''"
#  "HIERARCH OAJ DET OUT16 OVSCX= '[8443:8469,4671:9340]'"
#  "HIERARCH OAJ DET OUT16 OVSCY= '[8443:9648,4671:4724]'"
#  "HIERARCH OAJ DET OUT16 IMSC= '[8470:9621,4725:9340]'"
#  'HIERARCH OAJ DET OUT16 GAIN= 0.92' 'HIERARCH OAJ DET OUT16 RON= 3.3300'
#  'HIERARCH OAJ DET OUT16 SATUR= 123000.0'
#  'HIERARCH OAJ GEN AMBI WIND SPDMEAN= 4.99'
#  'HIERARCH OAJ GEN AMBI WIND SPDRMS= 5.01'
#  'HIERARCH OAJ GEN AMBI WIND DIRMEAN= 36.9'
#  'HIERARCH OAJ GEN AMBI WIND DIRRMS= 36.8'
#  'HIERARCH OAJ GEN AMBI RHUMMEAN= 43.5'
#  'HIERARCH OAJ GEN AMBI RHUMRMS= 43.5'
#  'HIERARCH OAJ GEN AMBI PRESMEAN= 811.35'
#  'HIERARCH OAJ GEN AMBI PRESRMS= 811.35'
#  'HIERARCH OAJ GEN AMBI TEMPMEAN= 5.922'
#  'HIERARCH OAJ GEN AMBI TEMPRMS= 5.931' "HIERARCH OAJ DPR CATG= 'SCIENCE'"
#  "HIERARCH OAJ DPR TYPE= 'OBJECT'" 'HIERARCH OAJ OCS BLOCK ID= 9023'
#  'HIERARCH OAJ OCS SHOT ID= 122887'
#  "CHECKSUM= 'c3DId0BHc0BHc0BH'   / HDU checksum updated 2017-04-10T04:55:33"
#  "DATASUM = '3274982704'         / data unit checksum updated 2017-04-10T04:55:33"
#  'SATURATE=                60000'
#  "HIERARCH OAJ PRO OVCODE = 'XO54P0YO27P27' / Code for the ov pr format"
#  '        83 cor STATS 2017-04-10T04:55:48.359982'
#  'HIERARCH OAJ QC NCMODE = 246.698 / Mode 83 cor image (ADU)'
#  'HIERARCH OAJ QC CORTOSTAT = 83 / Corretions applied when stats'
#  'HIERARCH OAJ QC NCMIDPT = 247.625 / Level estim 83 cor (ADU)'
#  'HIERARCH OAJ QC NCMIDRMS = 2.4424 / rms level estim 83 cor (ADU)'
#  'HIERARCH OAJ QC NCNOISE = 16.634 / Noise estim 83 cor (ADU)'
#  'HIERARCH OAJ QC NCNOIRMS = 0.5931999999999999 / rms noise estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT1 NCMODE = 240.319 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT1 NCMIDPT = 240.896 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT1 NCMIDRMS = 3.2705 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT1 NCNOISE = 16.701 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT1 NCNOIRMS = 0.5746 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT2 NCMODE = 245.634 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT2 NCMIDPT = 246.32 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT2 NCMIDRMS = 2.4551 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT2 NCNOISE = 16.689 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT2 NCNOIRMS = 0.5881999999999999 / rms noise amp estim 83 cor'
#  'HIERARCH OAJ QC OUT3 NCMODE = 248.011 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT3 NCMIDPT = 248.441 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT3 NCMIDRMS = 1.6735 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT3 NCNOISE = 16.633 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT3 NCNOIRMS = 0.5649999999999999 / rms noise amp estim 83 cor'
#  'HIERARCH OAJ QC OUT4 NCMODE = 247.866 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT4 NCMIDPT = 248.254 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT4 NCMIDRMS = 1.3728 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT4 NCNOISE = 16.659 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT4 NCNOIRMS = 0.6383 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT5 NCMODE = 248.0 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT5 NCMIDPT = 248.611 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT5 NCMIDRMS = 1.0973 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT5 NCNOISE = 16.597 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT5 NCNOIRMS = 0.6303 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT6 NCMODE = 247.553 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT6 NCMIDPT = 248.458 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT6 NCMIDRMS = 1.0724 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT6 NCNOISE = 16.646 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT6 NCNOIRMS = 0.6304999999999999 / rms noise amp estim 83 cor'
#  'HIERARCH OAJ QC OUT7 NCMODE = 248.3 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT7 NCMIDPT = 248.594 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT7 NCMIDRMS = 1.3781 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT7 NCNOISE = 16.72 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT7 NCNOIRMS = 0.6391 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT8 NCMODE = 246.4 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT8 NCMIDPT = 247.221 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT8 NCMIDRMS = 1.761 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT8 NCNOISE = 16.702 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT8 NCNOIRMS = 0.6183999999999999 / rms noise amp estim 83 cor'
#  'HIERARCH OAJ QC OUT9 NCMODE = 247.724 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT9 NCMIDPT = 248.833 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT9 NCMIDRMS = 3.3245 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT9 NCNOISE = 16.793 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT9 NCNOIRMS = 0.5877 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT10 NCMODE = 250.692 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT10 NCMIDPT = 251.026 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT10 NCMIDRMS = 1.6868 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT10 NCNOISE = 16.799 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT10 NCNOIRMS = 0.5896 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT11 NCMODE = 251.303 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT11 NCMIDPT = 252.264 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT11 NCMIDRMS = 1.8522 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT11 NCNOISE = 16.736 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT11 NCNOIRMS = 0.658 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT12 NCMODE = 251.272 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT12 NCMIDPT = 251.494 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT12 NCMIDRMS = 3.1213 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT12 NCNOISE = 16.912 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT12 NCNOIRMS = 0.5397 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT13 NCMODE = 247.752 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT13 NCMIDPT = 249.919 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT13 NCMIDRMS = 2.1115 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT13 NCNOISE = 16.371 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT13 NCNOIRMS = 0.4767 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT14 NCMODE = 245.411 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT14 NCMIDPT = 247.147 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT14 NCMIDRMS = 2.4981 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT14 NCNOISE = 16.43 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT14 NCNOIRMS = 0.454 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT15 NCMODE = 242.072 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT15 NCMIDPT = 244.476 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT15 NCMIDRMS = 3.6795 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT15 NCNOISE = 16.458 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT15 NCNOIRMS = 0.6163 / rms noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT16 NCMODE = 238.859 / Mode amp 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT16 NCMIDPT = 240.049 / Level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT16 NCMIDRMS = 3.9209 / rms level amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT16 NCNOISE = 16.305 / Noise amp estim 83 cor (ADU)'
#  'HIERARCH OAJ QC OUT16 NCNOIRMS = 0.6419 / rms noise amp estim 83 cor (ADU)'
#  "HIERARCH OAJ PRO IMGTYPE = 'SCIE    ' / Observation type"
#  'HIERARCH OAJ PRO OUT1 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT1 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT1 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT1 IMSC = '[1:1152, 1:4616]'"
#  "HIERARCH OAJ PRO OUT1 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT1 BILEVYP0 = -0.03915021778368932'
#  'HIERARCH OAJ PRO OUT1 BILEVYP1 = -0.00062477021693984'
#  'HIERARCH OAJ PRO OUT1 BILEVYP2 = 3.96834321846645E-06'
#  'HIERARCH OAJ PRO OUT1 BILEVYP3 = -8.2594852768484E-09'
#  'HIERARCH OAJ PRO OUT1 BILEVYP4 = 8.59027018826899E-12'
#  'HIERARCH OAJ PRO OUT1 BILEVYP5 = -5.0854170534380E-15'
#  'HIERARCH OAJ PRO OUT1 BILEVYP6 = 1.79159646658249E-18'
#  'HIERARCH OAJ PRO OUT1 BILEVYP7 = -3.7173921691396E-22'
#  'HIERARCH OAJ PRO OUT1 BILEVYP8 = 4.19290026524921E-26'
#  'HIERARCH OAJ PRO OUT1 BILEVYP9 = -1.9823739497339E-30'
#  "HIERARCH OAJ PRO OUT1 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT2 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT2 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT2 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT2 IMSC = '[1153:2304, 1:4616]'"
#  "HIERARCH OAJ PRO OUT2 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT2 BILEVYP0 = -0.01182954214017714'
#  'HIERARCH OAJ PRO OUT2 BILEVYP1 = -0.00082547813635210'
#  'HIERARCH OAJ PRO OUT2 BILEVYP2 = 5.61555099281217E-06'
#  'HIERARCH OAJ PRO OUT2 BILEVYP3 = -1.2211654208392E-08'
#  'HIERARCH OAJ PRO OUT2 BILEVYP4 = 1.29883649035438E-11'
#  'HIERARCH OAJ PRO OUT2 BILEVYP5 = -7.7855018202121E-15'
#  'HIERARCH OAJ PRO OUT2 BILEVYP6 = 2.76472537902357E-18'
#  'HIERARCH OAJ PRO OUT2 BILEVYP7 = -5.7725417768136E-22'
#  'HIERARCH OAJ PRO OUT2 BILEVYP8 = 6.55158858644544E-26'
#  'HIERARCH OAJ PRO OUT2 BILEVYP9 = -3.1199846315266E-30'
#  "HIERARCH OAJ PRO OUT2 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT3 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT3 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT3 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT3 IMSC = '[2305:3456, 1:4616]'"
#  "HIERARCH OAJ PRO OUT3 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT3 BILEVYP0 = 0.3892901897305102'
#  'HIERARCH OAJ PRO OUT3 BILEVYP1 = -0.00329516941528687'
#  'HIERARCH OAJ PRO OUT3 BILEVYP2 = 1.10328799789254E-05'
#  'HIERARCH OAJ PRO OUT3 BILEVYP3 = -1.7971703744191E-08'
#  'HIERARCH OAJ PRO OUT3 BILEVYP4 = 1.64618921943311E-11'
#  'HIERARCH OAJ PRO OUT3 BILEVYP5 = -9.0653984984783E-15'
#  'HIERARCH OAJ PRO OUT3 BILEVYP6 = 3.06166596592243E-18'
#  'HIERARCH OAJ PRO OUT3 BILEVYP7 = -6.2053098552261E-22'
#  'HIERARCH OAJ PRO OUT3 BILEVYP8 = 6.92581046035057E-26'
#  'HIERARCH OAJ PRO OUT3 BILEVYP9 = -3.2713858789762E-30'
#  "HIERARCH OAJ PRO OUT3 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT4 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT4 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT4 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT4 IMSC = '[3457:4608, 1:4616]'"
#  "HIERARCH OAJ PRO OUT4 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT4 BILEVYP0 = 0.7042174747553366'
#  'HIERARCH OAJ PRO OUT4 BILEVYP1 = -0.00467355832089176'
#  'HIERARCH OAJ PRO OUT4 BILEVYP2 = 1.21470967088760E-05'
#  'HIERARCH OAJ PRO OUT4 BILEVYP3 = -1.6475947716708E-08'
#  'HIERARCH OAJ PRO OUT4 BILEVYP4 = 1.32569759587247E-11'
#  'HIERARCH OAJ PRO OUT4 BILEVYP5 = -6.6652324972341E-15'
#  'HIERARCH OAJ PRO OUT4 BILEVYP6 = 2.10896879470327E-18'
#  'HIERARCH OAJ PRO OUT4 BILEVYP7 = -4.0690921773540E-22'
#  'HIERARCH OAJ PRO OUT4 BILEVYP8 = 4.36337996909051E-26'
#  'HIERARCH OAJ PRO OUT4 BILEVYP9 = -1.9899826790070E-30'
#  "HIERARCH OAJ PRO OUT4 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT5 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT5 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT5 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT5 IMSC = '[4609:5760, 1:4616]'"
#  "HIERARCH OAJ PRO OUT5 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT5 BILEVYP0 = 0.9134247855043317'
#  'HIERARCH OAJ PRO OUT5 BILEVYP1 = -0.00602607835017637'
#  'HIERARCH OAJ PRO OUT5 BILEVYP2 = 1.51289857390285E-05'
#  'HIERARCH OAJ PRO OUT5 BILEVYP3 = -1.9447321255523E-08'
#  'HIERARCH OAJ PRO OUT5 BILEVYP4 = 1.45785777707034E-11'
#  'HIERARCH OAJ PRO OUT5 BILEVYP5 = -6.7432841567807E-15'
#  'HIERARCH OAJ PRO OUT5 BILEVYP6 = 1.94671364378908E-18'
#  'HIERARCH OAJ PRO OUT5 BILEVYP7 = -3.4066748133356E-22'
#  'HIERARCH OAJ PRO OUT5 BILEVYP8 = 3.29602325505132E-26'
#  'HIERARCH OAJ PRO OUT5 BILEVYP9 = -1.3487951059732E-30'
#  "HIERARCH OAJ PRO OUT5 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT6 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT6 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT6 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT6 IMSC = '[5761:6912, 1:4616]'"
#  "HIERARCH OAJ PRO OUT6 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT6 BILEVYP0 = 0.5604891903659223'
#  'HIERARCH OAJ PRO OUT6 BILEVYP1 = -0.00344148651600036'
#  'HIERARCH OAJ PRO OUT6 BILEVYP2 = 8.49093104657006E-06'
#  'HIERARCH OAJ PRO OUT6 BILEVYP3 = -1.0966993259466E-08'
#  'HIERARCH OAJ PRO OUT6 BILEVYP4 = 8.17862595477757E-12'
#  'HIERARCH OAJ PRO OUT6 BILEVYP5 = -3.6657154286220E-15'
#  'HIERARCH OAJ PRO OUT6 BILEVYP6 = 9.9139259343136E-19'
#  'HIERARCH OAJ PRO OUT6 BILEVYP7 = -1.5611605061617E-22'
#  'HIERARCH OAJ PRO OUT6 BILEVYP8 = 1.28992965993018E-26'
#  'HIERARCH OAJ PRO OUT6 BILEVYP9 = -4.1616316638543E-31'
#  "HIERARCH OAJ PRO OUT6 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT7 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT7 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT7 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT7 IMSC = '[6913:8064, 1:4616]'"
#  "HIERARCH OAJ PRO OUT7 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT7 BILEVYP0 = 0.1304048104237522'
#  'HIERARCH OAJ PRO OUT7 BILEVYP1 = -0.00140490906064119'
#  'HIERARCH OAJ PRO OUT7 BILEVYP2 = 4.93174727368783E-06'
#  'HIERARCH OAJ PRO OUT7 BILEVYP3 = -7.8812173307438E-09'
#  'HIERARCH OAJ PRO OUT7 BILEVYP4 = 6.99213430018150E-12'
#  'HIERARCH OAJ PRO OUT7 BILEVYP5 = -3.7619895914036E-15'
#  'HIERARCH OAJ PRO OUT7 BILEVYP6 = 1.25699207417872E-18'
#  'HIERARCH OAJ PRO OUT7 BILEVYP7 = -2.5455589670479E-22'
#  'HIERARCH OAJ PRO OUT7 BILEVYP8 = 2.85661514563552E-26'
#  'HIERARCH OAJ PRO OUT7 BILEVYP9 = -1.3612425784080E-30'
#  "HIERARCH OAJ PRO OUT7 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT8 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT8 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT8 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT8 IMSC = '[8065:9216, 1:4616]'"
#  "HIERARCH OAJ PRO OUT8 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT8 BILEVYP0 = -0.1296877303044824'
#  'HIERARCH OAJ PRO OUT8 BILEVYP1 = 0.000456689763608943'
#  'HIERARCH OAJ PRO OUT8 BILEVYP2 = -2.9553737436625E-07'
#  'HIERARCH OAJ PRO OUT8 BILEVYP3 = -5.9652237896432E-10'
#  'HIERARCH OAJ PRO OUT8 BILEVYP4 = 1.19896541452880E-12'
#  'HIERARCH OAJ PRO OUT8 BILEVYP5 = -9.3193929909155E-16'
#  'HIERARCH OAJ PRO OUT8 BILEVYP6 = 3.90075573062750E-19'
#  'HIERARCH OAJ PRO OUT8 BILEVYP7 = -9.2167757988405E-23'
#  'HIERARCH OAJ PRO OUT8 BILEVYP8 = 1.15660902641922E-26'
#  'HIERARCH OAJ PRO OUT8 BILEVYP9 = -5.9937203041886E-31'
#  "HIERARCH OAJ PRO OUT8 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT9 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT9 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT9 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT9 IMSC = '[1:1152, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT9 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT9 BILEVYP0 = 0.09541103341113599'
#  'HIERARCH OAJ PRO OUT9 BILEVYP1 = -0.00127640160350755'
#  'HIERARCH OAJ PRO OUT9 BILEVYP2 = 5.69737564815283E-06'
#  'HIERARCH OAJ PRO OUT9 BILEVYP3 = -1.1355581496593E-08'
#  'HIERARCH OAJ PRO OUT9 BILEVYP4 = 1.18621122374757E-11'
#  'HIERARCH OAJ PRO OUT9 BILEVYP5 = -7.1426296586662E-15'
#  'HIERARCH OAJ PRO OUT9 BILEVYP6 = 2.57413007399465E-18'
#  'HIERARCH OAJ PRO OUT9 BILEVYP7 = -5.4843851217198E-22'
#  'HIERARCH OAJ PRO OUT9 BILEVYP8 = 6.37098020215158E-26'
#  'HIERARCH OAJ PRO OUT9 BILEVYP9 = -3.1101853584907E-30'
#  "HIERARCH OAJ PRO OUT9 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT10 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT10 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT10 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT10 IMSC = '[1153:2304, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT10 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT10 BILEVYP0 = -0.00144792827290872'
#  'HIERARCH OAJ PRO OUT10 BILEVYP1 = -0.00013886731984922'
#  'HIERARCH OAJ PRO OUT10 BILEVYP2 = 5.03468259571943E-07'
#  'HIERARCH OAJ PRO OUT10 BILEVYP3 = -1.3417124817769E-09'
#  'HIERARCH OAJ PRO OUT10 BILEVYP4 = 1.89960659912405E-12'
#  'HIERARCH OAJ PRO OUT10 BILEVYP5 = -1.4320509615742E-15'
#  'HIERARCH OAJ PRO OUT10 BILEVYP6 = 6.08348601093433E-19'
#  'HIERARCH OAJ PRO OUT10 BILEVYP7 = -1.4684625167491E-22'
#  'HIERARCH OAJ PRO OUT10 BILEVYP8 = 1.88192174121723E-26'
#  'HIERARCH OAJ PRO OUT10 BILEVYP9 = -9.9454487132408E-31'
#  "HIERARCH OAJ PRO OUT10 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT11 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT11 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT11 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT11 IMSC = '[2305:3456, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT11 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT11 BILEVYP0 = 0.03930667662242035'
#  'HIERARCH OAJ PRO OUT11 BILEVYP1 = -0.00170115414092957'
#  'HIERARCH OAJ PRO OUT11 BILEVYP2 = 6.59735468813366E-06'
#  'HIERARCH OAJ PRO OUT11 BILEVYP3 = -1.0694074242678E-08'
#  'HIERARCH OAJ PRO OUT11 BILEVYP4 = 9.24248641615790E-12'
#  'HIERARCH OAJ PRO OUT11 BILEVYP5 = -4.6901862148719E-15'
#  'HIERARCH OAJ PRO OUT11 BILEVYP6 = 1.44144384518757E-18'
#  'HIERARCH OAJ PRO OUT11 BILEVYP7 = -2.6350621938421E-22'
#  'HIERARCH OAJ PRO OUT11 BILEVYP8 = 2.63272812967466E-26'
#  'HIERARCH OAJ PRO OUT11 BILEVYP9 = -1.1057088968481E-30'
#  "HIERARCH OAJ PRO OUT11 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT12 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT12 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT12 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT12 IMSC = '[3457:4608, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT12 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT12 BILEVYP0 = -0.03312539239007799'
#  'HIERARCH OAJ PRO OUT12 BILEVYP1 = -0.00058739238012126'
#  'HIERARCH OAJ PRO OUT12 BILEVYP2 = 7.52032102881731E-07'
#  'HIERARCH OAJ PRO OUT12 BILEVYP3 = 1.15121154379010E-09'
#  'HIERARCH OAJ PRO OUT12 BILEVYP4 = -2.7293061495685E-12'
#  'HIERARCH OAJ PRO OUT12 BILEVYP5 = 2.09499698327575E-15'
#  'HIERARCH OAJ PRO OUT12 BILEVYP6 = -8.1480773932510E-19'
#  'HIERARCH OAJ PRO OUT12 BILEVYP7 = 1.73107653430723E-22'
#  'HIERARCH OAJ PRO OUT12 BILEVYP8 = -1.9143520344697E-26'
#  'HIERARCH OAJ PRO OUT12 BILEVYP9 = 8.62272759833569E-31'
#  "HIERARCH OAJ PRO OUT12 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT13 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT13 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT13 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT13 IMSC = '[4609:5760, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT13 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT13 BILEVYP0 = -0.1246561132393548'
#  'HIERARCH OAJ PRO OUT13 BILEVYP1 = 0.001111897333002732'
#  'HIERARCH OAJ PRO OUT13 BILEVYP2 = -4.6794037532559E-06'
#  'HIERARCH OAJ PRO OUT13 BILEVYP3 = 8.47487937572731E-09'
#  'HIERARCH OAJ PRO OUT13 BILEVYP4 = -8.0756639229816E-12'
#  'HIERARCH OAJ PRO OUT13 BILEVYP5 = 4.45093273212332E-15'
#  'HIERARCH OAJ PRO OUT13 BILEVYP6 = -1.4648584263293E-18'
#  'HIERARCH OAJ PRO OUT13 BILEVYP7 = 2.83213908630833E-22'
#  'HIERARCH OAJ PRO OUT13 BILEVYP8 = -2.9585606665570E-26'
#  'HIERARCH OAJ PRO OUT13 BILEVYP9 = 1.28427198208981E-30'
#  "HIERARCH OAJ PRO OUT13 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT14 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT14 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT14 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT14 IMSC = '[5761:6912, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT14 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT14 BILEVYP0 = 0.06537706962701242'
#  'HIERARCH OAJ PRO OUT14 BILEVYP1 = -0.0011708465947588'
#  'HIERARCH OAJ PRO OUT14 BILEVYP2 = 5.58588321066326E-06'
#  'HIERARCH OAJ PRO OUT14 BILEVYP3 = -1.1928979124813E-08'
#  'HIERARCH OAJ PRO OUT14 BILEVYP4 = 1.33501154043505E-11'
#  'HIERARCH OAJ PRO OUT14 BILEVYP5 = -8.5392141113129E-15'
#  'HIERARCH OAJ PRO OUT14 BILEVYP6 = 3.23016914221560E-18'
#  'HIERARCH OAJ PRO OUT14 BILEVYP7 = -7.1361630484483E-22'
#  'HIERARCH OAJ PRO OUT14 BILEVYP8 = 8.50261917206084E-26'
#  'HIERARCH OAJ PRO OUT14 BILEVYP9 = -4.2186389681051E-30'
#  "HIERARCH OAJ PRO OUT14 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT15 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT15 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT15 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT15 IMSC = '[6913:8064, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT15 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT15 BILEVYP0 = -0.07940398402518277'
#  'HIERARCH OAJ PRO OUT15 BILEVYP1 = 0.000634989569210153'
#  'HIERARCH OAJ PRO OUT15 BILEVYP2 = -1.2880793188182E-06'
#  'HIERARCH OAJ PRO OUT15 BILEVYP3 = 3.76782507393761E-10'
#  'HIERARCH OAJ PRO OUT15 BILEVYP4 = 1.16061263224812E-12'
#  'HIERARCH OAJ PRO OUT15 BILEVYP5 = -1.3704334809961E-15'
#  'HIERARCH OAJ PRO OUT15 BILEVYP6 = 6.77909633299495E-19'
#  'HIERARCH OAJ PRO OUT15 BILEVYP7 = -1.7564233468889E-22'
#  'HIERARCH OAJ PRO OUT15 BILEVYP8 = 2.33886398572862E-26'
#  'HIERARCH OAJ PRO OUT15 BILEVYP9 = -1.2646234649329E-30'
#  "HIERARCH OAJ PRO OUT15 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO OUT16 BILEVCOR = T'
#  "HIERARCH OAJ PRO OUT16 BILEVVAX = 'spline deg=5'"
#  'HIERARCH OAJ PRO OUT16 IMATRIM = T'
#  "HIERARCH OAJ PRO OUT16 IMSC = '[8065:9216, 4617:9232]'"
#  "HIERARCH OAJ PRO OUT16 BILEVVAY = 'polynomial deg=9'"
#  'HIERARCH OAJ PRO OUT16 BILEVYP0 = -0.05683689718324345'
#  'HIERARCH OAJ PRO OUT16 BILEVYP1 = -3.5879432045818E-07'
#  'HIERARCH OAJ PRO OUT16 BILEVYP2 = 2.58476260661904E-06'
#  'HIERARCH OAJ PRO OUT16 BILEVYP3 = -7.9936389396810E-09'
#  'HIERARCH OAJ PRO OUT16 BILEVYP4 = 1.02117354665407E-11'
#  'HIERARCH OAJ PRO OUT16 BILEVYP5 = -6.9232928402045E-15'
#  'HIERARCH OAJ PRO OUT16 BILEVYP6 = 2.69649612963760E-18'
#  'HIERARCH OAJ PRO OUT16 BILEVYP7 = -6.0584063928206E-22'
#  'HIERARCH OAJ PRO OUT16 BILEVYP8 = 7.30120423858036E-26'
#  'HIERARCH OAJ PRO OUT16 BILEVYP9 = -3.6550573168788E-30'
#  "HIERARCH OAJ PRO OUT16 IMSC = '[1:9648, 1:9340]'"
#  'HIERARCH OAJ PRO IMATRIM = T'
#  "HIERARCH OAJ PRO DATASEC = '[1:9216, 1:9232]'"
#  '        TRIM correction 2017-04-10T04:55:14.719576'
#  '        OVSC correction 2017-04-10T04:55:14.719576'
#  '        FLAT correction 2017-04-10T04:55:15.386758'
#  'HIERARCH OAJ PRO MASKSET = 95 / key to control updated masks'
#  'HIERARCH OAJ PRO CORDONE = 83 / corrections applied'
#  'HIERARCH OAJ PRO CORREQ = 595 / corrections required'
#  'HIERARCH OAJ PRO FLATCORR = T'
#  "HIERARCH OAJ PRO FLATFILE = 'j02-FLAS-b20170125e0309-zSDSS-00-C01M5V2'"
#  '        FRIN correction 2017-04-10T04:55:28.600343'
#  'HIERARCH OAJ PRO FLDATSUM = 2215427448 / CF datasum'
#  'HIERARCH OAJ PRO FRINCORR = T'
#  "HIERARCH OAJ PRO FRINFILE = 'j02-FRIN-b20160806e0111-zSDSS-00-C01M5'"
#  'HIERARCH OAJ PRO FRDATSUM = 2453630772 / CF datasum'
#  'HIERARCH OAJ PRO FRINGFAC = 0.258 / scale applied to fringing'
#  'HIERARCH OAJ PRO PROCMODE = 1 / 0=standard/1=prepro/2=nonstandard'
#  "HIERARCH OAJ PRO PIPVERS = '0.9.1   '"
#  '        FWHM ESTIM 2017-04-10T04:56:04.723818'
#  'HIERARCH OAJ PRO FWHMSEXT = 0.961 / FWHM arcsec estimated with SE'
#  'HIERARCH OAJ PRO FWHMSRMS = 0.049 / rms in FWHM with SE'
#  '        Astrometry done in 2017-04-10T04:56:17.057139'
#  "HIERARCH OAJ PRO ASTROMSOFT = 'Scamp   '"
#  'EQUINOX =        2000.00000000 / Mean equinox'
#  "RADESYS = 'ICRS    '           / Astrometric system"
#  "CTYPE1  = 'RA---TAN'           / WCS projection type for this axis"
#  "CTYPE2  = 'DEC--TAN'           / WCS projection type for this axis"
#  "CUNIT1  = 'deg     '           / Axis unit"
#  "CUNIT2  = 'deg     '           / Axis unit"
#  'CRVAL1  =   1.674092934012E+02 / World coordinate on this axis'
#  'CRVAL2  =   3.595673473471E+01 / World coordinate on this axis'
#  'CRPIX1  =   4.608500000000E+03 / Reference pixel on this axis'
#  'CRPIX2  =   4.616500000000E+03 / Reference pixel on this axis'
#  'CD1_1   =   1.544152742812E-04 / Linear projection matrix'
#  'CD1_2   =   9.372612311514E-07 / Linear projection matrix'
#  'CD2_1   =  -9.447326653439E-07 / Linear projection matrix'
#  'CD2_2   =   1.544059005698E-04 / Linear projection matrix'
#  'PV1_0   =   3.009314281685E-05 / Projection distortion parameter'
#  'PV1_1   =   1.002306891215E+00 / Projection distortion parameter'
#  'PV1_2   =  -5.249618222059E-05 / Projection distortion parameter'
#  'PV1_4   =  -2.309756482224E-04 / Projection distortion parameter'
#  'PV1_5   =   2.183300253067E-04 / Projection distortion parameter'
#  'PV1_6   =  -2.113648749132E-04 / Projection distortion parameter'
#  'PV1_7   =  -6.104793145023E-03 / Projection distortion parameter'
#  'PV1_8   =   1.531432525203E-04 / Projection distortion parameter'
#  'PV1_9   =  -5.309731969936E-03 / Projection distortion parameter'
#  'PV1_10  =   2.414286083485E-04 / Projection distortion parameter'
#  'PV2_0   =  -7.726005266473E-05 / Projection distortion parameter'
#  'PV2_1   =   1.002181920579E+00 / Projection distortion parameter'
#  'PV2_2   =   4.178825700402E-04 / Projection distortion parameter'
#  'PV2_4   =   2.072746481301E-04 / Projection distortion parameter'
#  'PV2_5   =  -1.738974762651E-04 / Projection distortion parameter'
#  'PV2_6   =   6.466688947300E-05 / Projection distortion parameter'
#  'PV2_7   =  -5.850221405016E-03 / Projection distortion parameter'
#  'PV2_8   =   1.785957276434E-04 / Projection distortion parameter'
#  'PV2_9   =  -6.119155593679E-03 / Projection distortion parameter'
#  'PV2_10  =  -1.160910433937E-04 / Projection distortion parameter'
#  'FGROUPNO=                    1 / SCAMP field group label'
#  'ASTIRMS1=   0.000000000000E+00 / Astrom. dispersion RMS (intern., high S/N)'
#  'ASTIRMS2=   0.000000000000E+00 / Astrom. dispersion RMS (intern., high S/N)'
#  'ASTRRMS1=   1.004188834473E-04 / Astrom. dispersion RMS (ref., high S/N)'
#  'ASTRRMS2=   7.595438506666E-05 / Astrom. dispersion RMS (ref., high S/N)'
#  'ASTINST =                    1 / SCAMP astrometric instrument label'
#  'FLXSCALE=   0.000000000000E+00 / SCAMP relative flux scale'
#  'MAGZEROP=           0.00000000 / SCAMP zero-point'
#  'PHOTIRMS=           0.00000000 / mag dispersion RMS (internal, high S/N)'
#  'PHOTINST=                    1 / SCAMP photometric instrument label'
#  'PHOTLINK=                    F / True if linked to a photometric field'
#  "ASTRPASS= 'INDIVIDUAL'         / astrometry pass IND/COADD"
#  'ASTRNOBJ=                  430 / astrom N objects astro (ref., low SN)'
#  'ASTRLCHI=                 29.0 / astrom Chi2 (ref., low SN)'
#  'ASTRNHOB=                  207 / astrom N objects astro (ref., high SN)'
#  'ASTRHCHI=                 38.0 / astrom Chi2 (ref., high SN)'
#  '        Interpolate bad pixels 2017-04-10T04:56:25.466743'
#  "HIERARCH OAJ PRO FIXPIX PRDATSU = '3274982704' / DATASUM before correctpix"
#  "HIERARCH OAJ PRO FIXPIX FUNCTIO = 'idw     ' / function used"
#  'HIERARCH OAJ PRO FIXPIX MASKVAL = 17 / mask values fixed'
#  'HIERARCH OAJ PRO FIXPIX MAXAREA = 3 / max area fixed'
#  "HIERARCH OAJ PRO FIXPIX MODE = 'morphology' / mode correctpixels"
#  'HISTORY   Astrometric solution by SCAMP version 2.0.4 (2017-01-20)'
#  "FITSFILE= 'j02-20170410T025351-01_prepro8957_4954_MEX1.fits' / File name of the"
#  'FITSEXT =                    1 / FITS Extension number'
#  'FITSNEXT=                    1 / Number of FITS image extensions in file'
#  "SEXVERS = 'SExtractor 2.23.1 - CEFCA 0.4' / Extraction software"
#  "SEXDATE = '10/04/2017'         / Extraction date"
#  "SEXTIME = '04:57:51'           / Extraction time"
#  'SEXELAPS=           8.00000000 / Elapsed time during extraction (s)'
#  'SEXBKGND=   2.478489379883E+02 / Median background level (ADU)'
#  'SEXBKDEV=   1.666131782532E+01 / Median background RMS (ADU)'
#  'SEXTHLD =   2.499197769165E+01 / Extraction threshold (ADU)'
#  'SEXATHLD=   2.499197769165E+01 / Analysis threshold (ADU)'
#  'SEXNDET =                 3785 / Number of raw detections'
#  'SEXNFIN =                 3213 / Final number of extracted sources'
#  'SEXNPARA=                   54 / Number of parameters per source'
#  'SEXPXSCL=   5.555999875069E-01 / Pixel scale used for measurements (arcsec)'
#  'SEXSFWHM=   9.610000252724E-01 / Source FWHM used for measurements (arcsec)'
#  "SEXNNWF = 'default.nnw'        / S/G classification NNW filename"
#  'SEXGAIN =   9.400000000000E-01 / Gain used (e-/ADU)'
#  'SEXFLTR =                    T / Detection filtering activated (flag)'
#  "SEXFILTN= 'default.conv'       / Filter filename"
#  'SEXMINAR=                    5 / Minimum area used for detection (pixels)'
#  'SEXDBLDN=                   32 / Number of deblending thresholds'
#  'SEXDBLDC=           0.00500000 / Minimum contrast used for deblending'
#  'SEXCLN  =                    T / Cleaning activated (flag)'
#  'SEXCLNPA=           1.00000000 / Cleaning parameter'
#  'SEXCLNST=                10000 / Cleaning stack-size'
#  'SEXAUTP1=           2.50000000 / Parameter #1 used for automatic magnitudes'
#  'SEXAUTP2=           3.50000000 / Parameter #2 used for automatic magnitudes'
#  'SEXPETP1=           2.50000000 / Parameter #1 used for Petronsian magnitudes'
#  'SEXPETP2=           3.50000000 / Parameter #2 used for Petrosian magnitudes'
#  'SEXSATLV=   6.000000000000E+04 / Saturation level used for flagging (ADU)'
#  'SEXMGZPT=          25.00000000 / Zero-point used for magnitudes'
#  'SEXMGGAM=           4.00000000 / Gamma used for photographic photometry'
#  'SEXBKGSX=                  256 / Mesh width used for background mapping (pixels)'
#  'SEXBKGSY=                  256 / Mesh height used for background mapping (pixels'
#  'SEXBKGFX=                    3 / Mask width used for background map filtering'
#  'SEXBKGFY=                    3 / Mask height used for background map filtering'
#  'SEXPBKGS=                   24 / Thickness used for local background (pixels)'
#  'SEXPIXSK=              3000000 / Pixel stack-size (pixels)'
#  'SEXFBUFS=                11000 / Image-buffer height (scanlines)'
#  'SEXMWSCL=   1.666131782532E+01 / Measurement-weight re-scaling factor'
#  'SEXDWSCL=   1.666131782532E+01 / Detection-weight re-scaling factor'
#  'SEXAPED1=    10.79913606911447 / Fixed photometric aperture #1 (pixels)'
#  'SEXAPED2=    1.799856011519078 / Fixed photometric aperture #2 (pixels)'
#  'SEXAPED3=    2.545380781809026 / Fixed photometric aperture #3 (pixels)'
#  'SEXAPED4=    3.599712023038157 / Fixed photometric aperture #4 (pixels)'
#  'SEXAPED5=    5.090761563618053 / Fixed photometric aperture #5 (pixels)'
#  'SEXAPED6=    7.199424046076316 / Fixed photometric aperture #6 (pixels)'
#  'SEXAPED7=    10.18152312723611 / Fixed photometric aperture #7 (pixels)'
#  'SEXAPED8=    14.39884809215263 / Fixed photometric aperture #8 (pixels)'
#  'SEXAPED9=    20.36304625447222 / Fixed photometric aperture #9 (pixels)'
#  'HIERARCH SEXAPED10 = 28.79769618430527 / Fixed photometric aperture #10 (pixels)'
#  'HIERARCH SEXAPED11 = 40.72609250894445 / Fixed photometric aperture #11 (pixels)'
#  'HIERARCH SEXAPED12 = 57.59539236861054 / Fixed photometric aperture #12 (pixels)'
#  'HIERARCH SEXAPED13 = 81.45218501788889 / Fixed photometric aperture #13 (pixels)'
#  'HIERARCH SEXAPED14 = 115.1907847372211 / Fixed photometric aperture #14 (pixels)'
#  'HIERARCH SEXAPED15 = 162.9043700357778 / Fixed photometric aperture #15 (pixels)'
#  'HIERARCH SEXAPED16 = 3.459323254139669 / Fixed photometric aperture #16 (pixels)'
#  'HIERARCH SEXAPED17 = 8.648308135349172 / Fixed photometric aperture #17 (pixels)'
#  'HIERARCH SEXAPED18 = 13.83729301655868 / Fixed photometric aperture #18 (pixels)'
#  'HIERARCH SEXAPED19 = 20.75593952483801 / Fixed photometric aperture #19 (pixels)'
#  'HIERARCH SEXAPED20 = 34.59323254139669 / Fixed photometric aperture #20 (pixels)'
#  'END                                                                            *']

# %%
#print image_header
image_data = hdu_list[1].data

# %%
print(type(image_data))
print(image_data.shape)
# Out:
# <type 'numpy.ndarray'>
# (9232, 9216)

# %%
hdu_list.close()

# %%
plt.imshow(image_data, cmap='gray')
plt.colorbar()

# To see more color maps
# http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps

# %%
from matplotlib.colors import LogNorm

# %%
plt.imshow(image_data, cmap='gray', norm=LogNorm())

# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[5.e3,1.e4,2.e4])
cbar.ax.set_yticklabels(['5,000','10,000','20,000'])
# Out:
# [<matplotlib.text.Text at 0x7f1ec6053050>,
#  <matplotlib.text.Text at 0x7f1ec605b750>,
#  <matplotlib.text.Text at 0x7f1ec5dc6a10>]
