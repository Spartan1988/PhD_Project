# %%
from astropy.io import fits
import pyfits
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
#matplotlib.rc_file("../../templates/matplotlibrc")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#hdu_list = fits.open("j02-20170410T025351-01_prepro.fz")
#hdu_list.info()
#catalog = fits.open("j02-20170410T025351-01_prepro.proccat")
catalog = pyfits.open("j02-20170410T025351-01_prepro.proccat")
catalog.info()
image_header = catalog[1].data[0][0]
data_catalog = catalog[2].data
#hdu_list[1].header
# Out:
# Filename: j02-20170410T025351-01_prepro.proccat
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1    LDAC_IMHEAD  BinTableHDU     12   1R x 1C      [63360A]
# 2    LDAC_OBJECTS  BinTableHDU    219   3213R x 54C   [1J, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1D, 1D, 1D, 1D, 1E, 1E, 1E, 1E, 1E, 1E, 1I, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1J, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 20E, 20E, 20E, 20E]

# %%
#image_header = catalog[1].header
print image_header
# Out:
# ['SIMPLE  =                    T / file does conform to FITS standard'
#  'BITPIX  =                  -32 / number of bits per data pixel'
#  'NAXIS   =                    2 / number of data axes'
#  'NAXIS1  =                 9216' 'NAXIS2  =                 9232'
#  'EXTEND  =                    T / FITS dataset may contain extensions'
#  "COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy"
#  "COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H"
#  "BUNIT   = 'adu'" "ORIGIN  = 'OAJ'"
#  "FILENAME= 'j02-20170410T025351-01_prepro.fits'" "TELESCOP= 'OAJ-T80'"
#  "INSTRUME= 'T80Cam'" "OBJECT  = 'HD095735off'" "PRJ_ID  = '1000096'"
#  "PRJ_VER = '11'" "OBS_ID  = '1'" "EXP_ID  = '36'" "OBSERVER= 'ROB'"
#  "PI-COI  = ''" "ORIGFILE= 'j02-20170410T025351-01.fits.fz'"
#  "DATE    = '2017-04-10T02:54:27.448'"
#  "DATE-OBS= '2017-04-10T02:53:51.897'"
#  "DATE-END= '2017-04-10T02:54:01.899'" 'EXPTIME = 10.000'
# ...

# %%
#print image_header
#image_data = hdu_list[1].data

# %%
#print(type(image_data))
#print(image_data.shape)

# %%
#hdu_list.close()

# %%
#plt.imshow(image_data, cmap='gray')
#plt.colorbar()

# To see more color maps
# http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps

# %%
#from matplotlib.colors import LogNorm

# %%
#plt.imshow(image_data, vmin=50, vmax=1800, cmap='gray')
#plt.imshow(image_data, cmap='gray',norm=LogNorm())

# I chose the tick marks based on the histogram above
#cbar = plt.colorbar(ticks=[5.e3,1.e4,2.e4])
#cbar.ax.set_yticklabels(['5,000','10,000','20,000'])

# %%
#header = hdu_list[1].header
#print ('Nome do Objeto: %s\n Filtro: %s\n Tempo de Exp.: %s\n'% (header['OBJECT'],header['FILTER'],header['EXPTIME']))

# %%
print image_header[13]
print image_header[22]
print image_header[24]
print image_header[25]
print image_header[26]
print image_header[29]
print image_header[32]
# Out:
# OBJECT  = 'HD095735off'
# DATE-OBS= '2017-04-10T02:53:51.897'
# EXPTIME = 10.000
# RA      = 167.394981
# DEC     = 35.96988
# AIRMASS = 1.80186
# FILTER  = 'zSDSS'

# %%
catalogo = fits.open("j02-20170410T025351-01_prepro.proccat")
catalogo.info()
# Out:
# Filename: j02-20170410T025351-01_prepro.proccat
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU       4   ()
#   1  LDAC_IMHEAD  BinTableHDU     12   1R x 1C   [63360A]
#   2  LDAC_OBJECTS  BinTableHDU    219   3213R x 54C   [1J, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1D, 1D, 1D, 1D, 1E, 1E, 1E, 1E, 1E, 1E, 1I, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1J, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 20E, 20E, 20E, 20E]

# %%
catalogo[2].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  534 / length of dimension 1
# NAXIS2  =                 3213 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   54 / number of table fields
# TTYPE1  = 'NUMBER  '
# TFORM1  = '1J      '
# TDISP1  = 'I10     '
# TTYPE2  = 'X_IMAGE '
# TFORM2  = '1E      '
# TUNIT2  = 'pixel   '
# TDISP2  = 'F11.4   '
# TTYPE3  = 'Y_IMAGE '
# TFORM3  = '1E      '
# TUNIT3  = 'pixel   '
# TDISP3  = 'F11.4   '
# TTYPE4  = 'THETA_WORLD'
# TFORM4  = '1E      '
# TUNIT4  = 'deg     '
# TDISP4  = 'F6.2    '
# TTYPE5  = 'ERRTHETA_WORLD'
# TFORM5  = '1E      '
# TUNIT5  = 'deg     '
# TDISP5  = 'F6.2    '
# TTYPE6  = 'ERRA_IMAGE'
# TFORM6  = '1E      '
# TUNIT6  = 'pixel   '
# TDISP6  = 'F9.5    '
# ...

# %%
print(data_catalog.columns)
# Out:
# ColDefs(
#     name = 'NUMBER'; format = '1J'; disp = 'I10'
#     name = 'X_IMAGE'; format = '1E'; unit = 'pixel'; disp = 'F11.4'
#     name = 'Y_IMAGE'; format = '1E'; unit = 'pixel'; disp = 'F11.4'
#     name = 'THETA_WORLD'; format = '1E'; unit = 'deg'; disp = 'F6.2'
#     name = 'ERRTHETA_WORLD'; format = '1E'; unit = 'deg'; disp = 'F6.2'
#     name = 'ERRA_IMAGE'; format = '1E'; unit = 'pixel'; disp = 'F9.5'
#     name = 'ERRB_IMAGE'; format = '1E'; unit = 'pixel'; disp = 'F9.5'
#     name = 'ERRTHETA_IMAGE'; format = '1E'; unit = 'deg'; disp = 'F6.2'
#     name = 'FLUX_AUTO'; format = '1E'; unit = 'count'; disp = 'G12.7'
#     name = 'FLUXERR_AUTO'; format = '1E'; unit = 'count'; disp = 'G12.7'
#     name = 'ALPHA_J2000'; format = '1D'; unit = 'deg'; disp = 'F11.7'
#     name = 'DELTA_J2000'; format = '1D'; unit = 'deg'; disp = 'F11.7'
#     name = 'X_WORLD'; format = '1D'; unit = 'deg'; disp = 'E18.10'
#     name = 'Y_WORLD'; format = '1D'; unit = 'deg'; disp = 'E18.10'
# ...

# %%
from astropy.table import Table
t = Table(data_catalog)                        # armazena a tabela na variavel t
print(t)
# Out:
# NUMBER X_IMAGE Y_IMAGE ...       FLUX_APER [20]      FLUXERR_APER [20]
# ------ ------- ------- ... ------------------------- ------------------
#      1 4179.14 6900.19 ... 5.77851e+06 .. 4.7667e+07 2810.35 .. 7292.54
#      2 5053.95 82.7841 ...        4888.23 .. 6972.83 176.291 .. 523.801
#      3 8912.54 79.5391 ...        1325.99 .. 1482.88 166.001 .. 519.527
#      4 7153.86 76.5726 ...        529.188 .. 630.738  163.635 .. 518.88
#      5 8591.21  66.377 ...        563.716 .. 1635.38 163.076 .. 519.564
#      6 7455.93 49.9776 ...        19348.1 .. 21466.8 215.389 .. 537.832
#      7 1442.99 50.3062 ...         2683.55 .. 3444.0 169.363 .. 521.018
#      8 5576.14 45.8436 ...        8858.04 .. 9367.51 188.123 .. 527.473
#      9 588.152 45.8044 ...        2661.81 .. 2991.53 169.615 .. 521.129
#     10 8599.95 27.6121 ...      464016.0 .. 511094.0 725.851 .. 898.319
#    ...     ...     ... ...                       ...                ...
# ...

# %%
print t['MAG_AUTO']
# Out:
# MAG_AUTO
# --------
#  3.55792
#  15.8473
#  17.1076
#  18.1289
#  18.2203
#  14.3013
#  16.4385
#   15.149
#  16.4209
#  10.7814
#      ...
#  17.9168
#  18.1895
#  18.3635
#  17.8032
#  18.3743
#  17.8492
#   18.328
#  17.4892
#  17.2083
#  13.0736
#  16.9951
# Length = 3213 rows

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy import wcs

# %%
c = SkyCoord(ra=167.394981*u.degree, dec=35.96988*u.degree)#, distance=770*u.kpc)
wcs.utils.skycoord_to_pixel(c.ra,c.dec)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-c993720b85a8> in <module>()
#       1 c = SkyCoord(ra=167.394981*u.degree, dec=35.96988*u.degree)#, distance=770*u.kpc)
# ----> 2 wcs.utils.skycoord_to_pixel(c.ra,c.dec)
#
# /usr/local/lib/python2.7/dist-packages/astropy/wcs/utils.pyc in skycoord_to_pixel(coords, wcs, origin, mode)
#     389     from . import WCSSUB_CELESTIAL
#     390
# --> 391     if _has_distortion(wcs) and wcs.naxis != 2:
#     392         raise ValueError("Can only handle WCS with distortions for 2-dimensional WCS")
#     393
#
# /usr/local/lib/python2.7/dist-packages/astropy/wcs/utils.pyc in _has_distortion(wcs)
#     354     """
#     355     return any(getattr(wcs, dist_attr) is not None
# --> 356                for dist_attr in ['cpdis1', 'cpdis2', 'det2im1', 'det2im2', 'sip'])
#     357
#     358
#
# ...
